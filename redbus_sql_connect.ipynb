# %%
import pandas as pd
import mysql.connector
import numpy as np

# %%
# csv to dataframe
df_buses_1=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Kerala Bus details.csv")
df_buses_2=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Andhra bus details")
df_buses_3=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Telangana bus details")
df_buses_4=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Rajasthan bus details")
df_buses_5=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\HP bus details")
df_buses_6=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Assam bus details")
df_buses_7=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\UP bus details")
df_buses_8=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\WB bus details")
df_buses_9=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Bihar bus details")
df_buses_10=pd.read_csv(r"C:\Users\hp\OneDrive\Documents\streamlit\Punjab bus details")

Final_df=pd.concat([df_buses_1,df_buses_2,df_buses_3,df_buses_4,df_buses_5,df_buses_6,
                    df_buses_7,df_buses_8,df_buses_9,df_buses_10],ignore_index=True)
Final_df
# Out:
#       Unnamed: 0                        Bus_name  \
# 0              0                   Kyros Connect
# 1              1    CHANCHALAS TOURS AND TRAVELS
# 2              2                   FAST LINE BUS
# 3              3  National travels and logistics
# 4              4                     MMK Travels
# ...          ...                             ...
# 2688          30                             NaN
# 2689          31                             NaN
# 2690          32                             NaN
# 2691          33                             NaN
# 2692          34                             NaN
#
#                                 Bus_type Start_time End_time Total_duration  \
# 0     Bharat Benz A/C Semi Sleeper (2+2)      23:00    09:00        10h 00m
# 1                 A/C Semi Sleeper (2+2)      19:45    06:00        10h 15m
# 2                      A/C Sleeper (2+1)      21:15    06:15        09h 00m
# ...

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       2693 non-null   int64
#  1   Bus_name         2648 non-null   object
#  2   Bus_type         2648 non-null   object
#  3   Start_time       2648 non-null   object
#  4   End_time         2648 non-null   object
#  5   Total_duration   2648 non-null   object
#  6   Price            2648 non-null   object
#  7   Seats_Available  2648 non-null   object
#  8   Ratings          2648 non-null   object
#  9   Route_link       2693 non-null   object
#  10  Route_name       2693 non-null   object
# dtypes: int64(1), object(10)
# memory usage: 231.6+ KB

# %%
Final_df.drop(['Unnamed: 0'],axis=1,inplace=True)

# %%
Final_df
# Out:
#                             Bus_name                            Bus_type  \
# 0                      Kyros Connect  Bharat Benz A/C Semi Sleeper (2+2)
# 1       CHANCHALAS TOURS AND TRAVELS              A/C Semi Sleeper (2+2)
# 2                      FAST LINE BUS                   A/C Sleeper (2+1)
# 3     National travels and logistics                   A/C Sleeper (2+1)
# 4                        MMK Travels          A/C Seater / Sleeper (2+1)
# ...                              ...                                 ...
# 2688                             NaN                                 NaN
# 2689                             NaN                                 NaN
# 2690                             NaN                                 NaN
# 2691                             NaN                                 NaN
# 2692                             NaN                                 NaN
#
#      Start_time End_time Total_duration     Price     Seats_Available  \
# ...

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2648 non-null   object
#  1   Bus_type         2648 non-null   object
#  2   Start_time       2648 non-null   object
#  3   End_time         2648 non-null   object
#  4   Total_duration   2648 non-null   object
#  5   Price            2648 non-null   object
#  6   Seats_Available  2648 non-null   object
#  7   Ratings          2648 non-null   object
#  8   Route_link       2693 non-null   object
#  9   Route_name       2693 non-null   object
# dtypes: object(10)
# memory usage: 210.5+ KB

# %%
#convert prices to numeric
Final_df["Price"]=Final_df["Price"].str.replace("INR","")
Final_df["Price"]=Final_df["Price"].astype(float)

# %%
Final_df["Price"].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26584\2485834454.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Price"].fillna(0,inplace=True)

# %%
Final_df["Price"]
# Out:
# 0       1899.0
# 1       1148.0
# 2       2699.0
# 3       1590.0
# 4        999.0
#          ...
# 2688       0.0
# 2689       0.0
# 2690       0.0
# 2691       0.0
# 2692       0.0
# Name: Price, Length: 2693, dtype: float64

# %%
#convert seat availability to numeric
Final_df["Seats_Available"]=Final_df["Seats_Available"].str.replace("Seats available","")
Final_df["Seats_Available"]=Final_df["Seats_Available"].str.strip()
Final_df["Seats_Available"]=Final_df["Seats_Available"].str.split().str[0]
Final_df["Seats_Available"].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26584\2466643899.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Seats_Available"].fillna(0,inplace=True)

# %%
Final_df["Seats_Available"]
# Out:
# 0       17
# 1        6
# 2       34
# 3        5
# 4        1
#         ..
# 2688     0
# 2689     0
# 2690     0
# 2691     0
# 2692     0
# Name: Seats_Available, Length: 2693, dtype: int64

# %%
Final_df["Seats_Available"] = pd.to_numeric(Final_df["Seats_Available"], errors='coerce')
Final_df["Seats_Available"].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26584\1227671526.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Seats_Available"].fillna(0,inplace=True)

# %%
#convert Ratings to numeric
Final_df["Ratings"]=Final_df["Ratings"].str.replace("New","")
Final_df["Ratings"]=Final_df["Ratings"].str.strip()
Final_df["Ratings"]=Final_df["Ratings"].str.split().str[0]
Final_df["Ratings"] = pd.to_numeric(Final_df["Ratings"], errors='coerce')
Final_df["Ratings"].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_26584\709375803.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Final_df["Ratings"].fillna(0,inplace=True)

# %%
Final_df["Ratings"]
# Out:
# 0       4.1
# 1       5.0
# 2       4.5
# 3       4.3
# 4       4.5
#        ...
# 2688    0.0
# 2689    0.0
# 2690    0.0
# 2691    0.0
# 2692    0.0
# Name: Ratings, Length: 2693, dtype: float64

# %%
Final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2693 entries, 0 to 2692
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Bus_name         2648 non-null   object
#  1   Bus_type         2648 non-null   object
#  2   Start_time       2648 non-null   object
#  3   End_time         2648 non-null   object
#  4   Total_duration   2648 non-null   object
#  5   Price            2693 non-null   float64
#  6   Seats_Available  2693 non-null   int64
#  7   Ratings          2693 non-null   float64
#  8   Route_link       2693 non-null   object
#  9   Route_name       2693 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 210.5+ KB

# %%
# replacing the nan value
Final_df = Final_df.replace({np.nan: None})

# %%
Final_df
# Out:
#                             Bus_name                            Bus_type  \
# 0                      Kyros Connect  Bharat Benz A/C Semi Sleeper (2+2)
# 1       CHANCHALAS TOURS AND TRAVELS              A/C Semi Sleeper (2+2)
# 2                      FAST LINE BUS                   A/C Sleeper (2+1)
# 3     National travels and logistics                   A/C Sleeper (2+1)
# 4                        MMK Travels          A/C Seater / Sleeper (2+1)
# ...                              ...                                 ...
# 2688                            None                                None
# 2689                            None                                None
# 2690                            None                                None
# 2691                            None                                None
# 2692                            None                                None
#
#      Start_time End_time Total_duration   Price  Seats_Available  Ratings  \
# ...

# %%
Final_df.to_csv("Redbus_Final_details.csv")

# %% [markdown]
# Create MySQL database

# %%
pip install mysql.connector

# %%
conn=mysql.connector.connect(host="localhost", user="root", password="lamiv@1998",database="RED_BUS_DETAILS",auth_plugin='mysql_native_password'
)
my_cursor = conn.cursor()

# %%
# Table Creation
my_cursor.execute('''CREATE TABLE IF NOT EXISTS bus_details(
                  ID INT AUTO_INCREMENT PRIMARY KEY,
                  Bus_name VARCHAR(255) NULL,
                  Bus_type VARCHAR(255) NULL,
                  Start_time VARCHAR(255) NULL,
                  End_time VARCHAR(255) NULL,
                  Total_duration VARCHAR(255) NULL,
                  Price FLOAT NULL,
                  Seats_Available VARCHAR(255) NULL,
                  Ratings Float NULL,
                  Route_link VARCHAR(255) NULL,
                  Route_name VARCHAR(255) NULL
                  )''')
print("Table Created successfully")
# Out:
# Table Created successfully

# %%
# SQL query to insert data into bus_details table
insert_query = '''INSERT INTO bus_details(
                    Bus_name,
                    Bus_type,
                    Start_time,
                    End_time,
                    Total_duration,
                    Price,
                    Seats_Available,
                    Ratings,
                    Route_link,
                    Route_name)
                  VALUES(%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)'''
data = Final_df.values.tolist()
my_cursor.executemany(insert_query, data)
conn.commit()

print("Values inserted successfully")
# Out:
# Values inserted successfully
